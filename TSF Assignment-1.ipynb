# %% [markdown]
# # The Spark Foundation #GRIPJUNE2021

# %% [markdown]
# # Task 1- Prediction using Supervised ML

# %% [markdown]
# # By Aditi Goyal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# Reading the Data 
data = pd.read_csv('http://bit.ly/w-data')
data.head(5)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# Check if there any null value in the Dataset
data.isnull == True
# Out:
# False

# %% [markdown]
# #### As No NULL value in the Dataset ,we will now visualize the Data.

# %%
sns.set_style('darkgrid')
sns.scatterplot(y= data['Scores'], x= data['Hours'])
plt.title('Marks Vs  Hours of Study',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours Studied', size=12)
plt.show()

# %% [markdown]
# #### Now,Lets plot a linear regression to confirm the correlation.

# %%
sns.regplot(x= data['Hours'], y= data['Scores'])
plt.title('Regression Plot',size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours of Study', size=12)
plt.show()
print(data.corr())
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %% [markdown]
# #### As, It is confirmed that the variables are positively correlated.

# %% [markdown]
# ### Training the Model

# %% [markdown]
# #### 1) Splitting the Data

# %%
# Defining X and y from the Data
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values

# Spliting the Data in two
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)

# %% [markdown]
# #### 2) Fitting the Data into the model

# %%
regression = LinearRegression()
regression.fit(train_X, train_y)
print("Model Trained Successfully!!!")
# Out:
# Model Trained Successfully!!!

# %% [markdown]
# #### Predicting the Percentage of Marks

# %%
pred_y = regression.predict(val_X)
prediction = pd.DataFrame({'Hours': [i[0] for i in val_X], 'Predicted Marks': [k for k in pred_y]})
prediction
# Out:
#    Hours  Predicted Marks
# 0    1.5        16.844722
# 1    3.2        33.745575
# 2    7.4        75.500624
# 3    2.5        26.786400
# 4    5.9        60.588106
# 5    3.8        39.710582
# 6    1.9        20.821393

# %% [markdown]
# #### Comparing the Predicted Marks with the Actual Marks

# %%
compare_marks = pd.DataFrame({'Actual Marks': val_y, 'Predicted Marks': pred_y})
compare_marks
# Out:
#    Actual Marks  Predicted Marks
# 0            20        16.844722
# 1            27        33.745575
# 2            69        75.500624
# 3            30        26.786400
# 4            62        60.588106
# 5            35        39.710582
# 6            24        20.821393

# %% [markdown]
# #### Visually Comparing the Predicted Marks with the Actual Marks

# %%
plt.scatter(x=val_X, y=val_y, color='blue')
plt.plot(val_X, pred_y, color='Black')
plt.title('Actual vs Predicted', size=20)
plt.ylabel('Marks Percentage', size=12)
plt.xlabel('Hours of Study', size=12)
plt.show()

# %% [markdown]
# #### Evaluating the Model

# %%
# Calculating the accuracy of the model
print('Mean absolute error: ',mean_absolute_error(val_y,pred_y))
# Out:
# Mean absolute error:  4.130879918502486

# %% [markdown]
#  Small value of Mean absolute shows that the chances of error or wrong forecasting through the model are very less.

# %% [markdown]
# ## What will be the predicted score of a student if he/she studies for 9.25 hrs/ day?

# %%
hours = [9.25]
answer = regression.predict([hours])
print("Score = {}".format(round(answer[0],3)))
# Out:
# Score = 93.893

# %% [markdown]
# #### According to the regression model if a student studies for 9.25 hours a day he/she is likely to score 93.89 marks.
